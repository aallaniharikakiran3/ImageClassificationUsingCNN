# %%
import warnings
warnings.filterwarnings('ignore')

import cv2
import numpy as np
import urllib.request
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Dropout, Flatten, BatchNormalization
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

# %%
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.1, random_state=0)

# %%
print('Train Images Shape:      ', X_train.shape)
print('Train Labels Shape:      ', y_train.shape)

print('\nValidation Images Shape: ', X_valid.shape)
print('Validation Labels Shape: ', y_valid.shape)

print('\nTest Images Shape:       ', X_test.shape)
print('Test Labels Shape:       ', y_test.shape)
# Out:
# Train Images Shape:       (45000, 32, 32, 3)
# Train Labels Shape:       (45000, 1)
#
# Validation Images Shape:  (5000, 32, 32, 3)
# Validation Labels Shape:  (5000, 1)
#
# Test Images Shape:        (10000, 32, 32, 3)
# Test Labels Shape:        (10000, 1)

# %%
# CIFAR-10 classes
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# Create a new figure
plt.figure(figsize=(15,15))

# Loop over the first 25 images
for i in range(64):
    # Create a subplot for each image
    plt.subplot(8, 8, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)

    # Display the image
    plt.imshow(X_train[i])

    # Set the label as the title
    plt.title(class_names[y_train[i][0]], fontsize=12)

# Display the figure
plt.show()

# %%
# Convert pixel values data type to float32
X_train = X_train.astype('float32')
X_test  = X_test.astype('float32')
X_valid = X_valid.astype('float32')

# Calculate the mean and standard deviation of the training images
mean = np.mean(X_train)
std  = np.std(X_train)

# Normalize the data
# The tiny value 1e-7 is added to prevent division by zero
X_train = (X_train-mean)/(std+1e-7)
X_test  = (X_test-mean) /(std+1e-7)
X_valid = (X_valid-mean)/(std+1e-7)

# %%
y_train = to_categorical(y_train, 10)
y_valid = to_categorical(y_valid, 10)
y_test  = to_categorical(y_test, 10)

# %%
# Data augmentation
data_generator = ImageDataGenerator(
    # Rotate images randomly by up to 15 degrees
    rotation_range=15,

    # Shift images horizontally by up to 12% of their width
    width_shift_range=0.12,

    # Shift images vertically by up to 12% of their height
    height_shift_range=0.12,

    # Randomly flip images horizontally
    horizontal_flip=True,

    # Zoom images in by up to 10%
    zoom_range=0.1,

    # Change brightness by up to 10%
    brightness_range=[0.9,1.1],

    # Shear intensity (shear angle in counter-clockwise direction in degrees)
    shear_range=10,

    # Channel shift intensity
    channel_shift_range=0.1,
)

# %%
# Initialize a sequential model
model = Sequential()

# Set the weight decay value for L2 regularization
weight_decay = 0.0001

# Add the first convolutional layer with 32 filters of size 3x3
model.add(Conv2D(filters=32, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay),
                 input_shape=X_train.shape[1:]))
# Add batch normalization layer
model.add(BatchNormalization())

# Add the second convolutional layer similar to the first
model.add(Conv2D(filters=32, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay)))
model.add(BatchNormalization())

# Add the first max pooling layer with pool size of 2x2
model.add(MaxPooling2D(pool_size=(2, 2)))
# Add dropout layer with 0.2 dropout rate
model.add(Dropout(rate=0.2))

# Add the third and fourth convolutional layers with 64 filters
model.add(Conv2D(filters=64, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay)))
model.add(BatchNormalization())
model.add(Conv2D(filters=64, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay)))
model.add(BatchNormalization())

# Add the second max pooling layer and increase dropout rate to 0.3
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.3))

# Add the fifth and sixth convolutional layers with 128 filters
model.add(Conv2D(filters=128, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay)))
model.add(BatchNormalization())
model.add(Conv2D(filters=128, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay)))
model.add(BatchNormalization())

# Add the third max pooling layer and increase dropout rate to 0.4
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.4))

# Add the seventh and eighth convolutional layers with 256 filters
model.add(Conv2D(filters=256, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay)))
model.add(BatchNormalization())
model.add(Conv2D(filters=256, kernel_size=(3,3), padding='same', activation='relu', kernel_regularizer=l2(weight_decay)))
model.add(BatchNormalization())

# Add the fourth max pooling layer and increase dropout rate to 0.5
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.5))

# Flatten the tensor output from the previous layer
model.add(Flatten())

# Add a fully connected layer with softmax activation function for outputting class probabilities
model.add(Dense(10, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 32, 32, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 16, 16, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 8, 8, 128)      │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 4, 4, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 4, 4, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 4, 4, 256)      │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 4, 4, 256)      │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 2, 2, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 2, 2, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 10)             │        10,250 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,186,346 (4.53 MB)
#  Trainable params: 1,184,426 (4.52 MB)
#  Non-trainable params: 1,920 (7.50 KB)

# %%
# Set the batch size for the training
batch_size = 64

# Set the maximum number of epochs for the training
epochs = 300

# Define the optimizer (Adam)
optimizer = Adam(learning_rate=0.0005)

# Compile the model with the defined optimizer, loss function, and metrics
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# Add ReduceLROnPlateau callback
# Here, the learning rate will be reduced by half (factor=0.5) if no improvement in validation loss is observed for 10 epochs
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, min_lr=0.00001)

# Add EarlyStopping callback
# Here, training will be stopped if no improvement in validation loss is observed for 40 epochs.
# The `restore_best_weights` parameter ensures that the model weights are reset to the values from the epoch
# with the best value of the monitored quantity (in this case, 'val_loss').
early_stopping = EarlyStopping(monitor='val_loss', patience=40, restore_best_weights=True, verbose=1)

# Fit the model on the training data, using the defined batch size and number of epochs
# The validation data is used to evaluate the model's performance during training
# The callbacks implemented are learning rate reduction when a plateau is reached in validation loss and
# stopping training early if no improvement is observed
history = model.fit(
    data_generator.flow(X_train, y_train, batch_size=batch_size),
    epochs=epochs,
    validation_data=(X_valid, y_valid),
    callbacks=[reduce_lr, early_stopping],
    verbose=2
)
# Out:
# Epoch 1/300
# 704/704 - 71s - 101ms/step - accuracy: 0.3350 - loss: 2.3480 - val_accuracy: 0.4334 - val_loss: 1.7998 - learning_rate: 5.0000e-04
# Epoch 2/300
# 704/704 - 44s - 62ms/step - accuracy: 0.4624 - loss: 1.7319 - val_accuracy: 0.5062 - val_loss: 1.5339 - learning_rate: 5.0000e-04
# Epoch 3/300
# 704/704 - 45s - 64ms/step - accuracy: 0.5249 - loss: 1.5290 - val_accuracy: 0.5746 - val_loss: 1.3754 - learning_rate: 5.0000e-04
# Epoch 4/300
# 704/704 - 44s - 63ms/step - accuracy: 0.5805 - loss: 1.3315 - val_accuracy: 0.6604 - val_loss: 1.0639 - learning_rate: 5.0000e-04
# Epoch 5/300
# 704/704 - 44s - 62ms/step - accuracy: 0.6167 - loss: 1.2311 - val_accuracy: 0.6554 - val_loss: 1.1099 - learning_rate: 5.0000e-04
# Epoch 6/300
# 704/704 - 44s - 63ms/step - accuracy: 0.6481 - loss: 1.1250 - val_accuracy: 0.6758 - val_loss: 1.0491 - learning_rate: 5.0000e-04
# Epoch 7/300
# 704/704 - 43s - 60ms/step - accuracy: 0.6710 - loss: 1.0674 - val_accuracy: 0.7092 - val_loss: 0.9729 - learning_rate: 5.0000e-04
# Epoch 8/300
# 704/704 - 43s - 61ms/step - accuracy: 0.6869 - loss: 1.0343 - val_accuracy: 0.7304 - val_loss: 0.9324 - learning_rate: 5.0000e-04
# Epoch 9/300
# 704/704 - 43s - 61ms/step - accuracy: 0.7033 - loss: 0.9880 - val_accuracy: 0.7568 - val_loss: 0.8594 - learning_rate: 5.0000e-04
# Epoch 10/300
# 704/704 - 44s - 63ms/step - accuracy: 0.7129 - loss: 0.9717 - val_accuracy: 0.7612 - val_loss: 0.8559 - learning_rate: 5.0000e-04
# Epoch 11/300
# 704/704 - 44s - 63ms/step - accuracy: 0.7305 - loss: 0.9251 - val_accuracy: 0.7630 - val_loss: 0.8541 - learning_rate: 5.0000e-04
# Epoch 12/300
# 704/704 - 44s - 63ms/step - accuracy: 0.7379 - loss: 0.9086 - val_accuracy: 0.7762 - val_loss: 0.7993 - learning_rate: 5.0000e-04
# Epoch 13/300
# 704/704 - 44s - 63ms/step - accuracy: 0.7465 - loss: 0.8885 - val_accuracy: 0.8022 - val_loss: 0.7269 - learning_rate: 5.0000e-04
# Epoch 14/300
# 704/704 - 45s - 64ms/step - accuracy: 0.7566 - loss: 0.8607 - val_accuracy: 0.7850 - val_loss: 0.7689 - learning_rate: 5.0000e-04
# Epoch 15/300
# 704/704 - 45s - 64ms/step - accuracy: 0.7612 - loss: 0.8586 - val_accuracy: 0.8118 - val_loss: 0.7136 - learning_rate: 5.0000e-04
# Epoch 16/300
# 704/704 - 44s - 63ms/step - accuracy: 0.7621 - loss: 0.8587 - val_accuracy: 0.8142 - val_loss: 0.7245 - learning_rate: 5.0000e-04
# Epoch 17/300
# 704/704 - 45s - 64ms/step - accuracy: 0.7708 - loss: 0.8413 - val_accuracy: 0.8002 - val_loss: 0.7680 - learning_rate: 5.0000e-04
# Epoch 18/300
# 704/704 - 44s - 62ms/step - accuracy: 0.7763 - loss: 0.8298 - val_accuracy: 0.8182 - val_loss: 0.7194 - learning_rate: 5.0000e-04
# Epoch 19/300
# 704/704 - 82s - 116ms/step - accuracy: 0.7799 - loss: 0.8192 - val_accuracy: 0.8236 - val_loss: 0.6993 - learning_rate: 5.0000e-04
# Epoch 20/300
# 704/704 - 46s - 65ms/step - accuracy: 0.7836 - loss: 0.8095 - val_accuracy: 0.8170 - val_loss: 0.7261 - learning_rate: 5.0000e-04
# Epoch 21/300
# 704/704 - 43s - 62ms/step - accuracy: 0.7887 - loss: 0.7944 - val_accuracy: 0.8242 - val_loss: 0.7099 - learning_rate: 5.0000e-04
# Epoch 22/300
# 704/704 - 44s - 63ms/step - accuracy: 0.7906 - loss: 0.7994 - val_accuracy: 0.8158 - val_loss: 0.7406 - learning_rate: 5.0000e-04
# Epoch 23/300
# 704/704 - 45s - 63ms/step - accuracy: 0.7960 - loss: 0.7848 - val_accuracy: 0.8292 - val_loss: 0.6921 - learning_rate: 5.0000e-04
# Epoch 24/300
# 704/704 - 44s - 63ms/step - accuracy: 0.7940 - loss: 0.7857 - val_accuracy: 0.8314 - val_loss: 0.7030 - learning_rate: 5.0000e-04
# Epoch 25/300
# 704/704 - 44s - 63ms/step - accuracy: 0.7993 - loss: 0.7787 - val_accuracy: 0.8360 - val_loss: 0.6939 - learning_rate: 5.0000e-04
# Epoch 26/300
# 704/704 - 43s - 62ms/step - accuracy: 0.8039 - loss: 0.7657 - val_accuracy: 0.8126 - val_loss: 0.7409 - learning_rate: 5.0000e-04
# Epoch 27/300
# 704/704 - 44s - 63ms/step - accuracy: 0.8076 - loss: 0.7567 - val_accuracy: 0.8264 - val_loss: 0.7230 - learning_rate: 5.0000e-04
# Epoch 28/300
# 704/704 - 45s - 64ms/step - accuracy: 0.8104 - loss: 0.7498 - val_accuracy: 0.8394 - val_loss: 0.6752 - learning_rate: 5.0000e-04
# Epoch 29/300
# 704/704 - 45s - 63ms/step - accuracy: 0.8097 - loss: 0.7507 - val_accuracy: 0.8384 - val_loss: 0.6774 - learning_rate: 5.0000e-04
# Epoch 30/300
# 704/704 - 45s - 64ms/step - accuracy: 0.8120 - loss: 0.7442 - val_accuracy: 0.8410 - val_loss: 0.6717 - learning_rate: 5.0000e-04
# Epoch 31/300
# 704/704 - 44s - 63ms/step - accuracy: 0.8127 - loss: 0.7497 - val_accuracy: 0.8412 - val_loss: 0.6842 - learning_rate: 5.0000e-04
# Epoch 32/300
# 704/704 - 45s - 64ms/step - accuracy: 0.8172 - loss: 0.7345 - val_accuracy: 0.8424 - val_loss: 0.6812 - learning_rate: 5.0000e-04
# Epoch 33/300
# 704/704 - 82s - 117ms/step - accuracy: 0.8217 - loss: 0.7239 - val_accuracy: 0.8436 - val_loss: 0.6833 - learning_rate: 5.0000e-04
# Epoch 34/300
# 704/704 - 45s - 63ms/step - accuracy: 0.8201 - loss: 0.7318 - val_accuracy: 0.8488 - val_loss: 0.6516 - learning_rate: 5.0000e-04
# Epoch 35/300
# 704/704 - 46s - 65ms/step - accuracy: 0.8210 - loss: 0.7249 - val_accuracy: 0.8422 - val_loss: 0.6765 - learning_rate: 5.0000e-04
# Epoch 36/300
# 704/704 - 46s - 65ms/step - accuracy: 0.8242 - loss: 0.7197 - val_accuracy: 0.8440 - val_loss: 0.6794 - learning_rate: 5.0000e-04
# Epoch 37/300
# 704/704 - 44s - 62ms/step - accuracy: 0.8260 - loss: 0.7136 - val_accuracy: 0.8538 - val_loss: 0.6540 - learning_rate: 5.0000e-04
# Epoch 38/300
# 704/704 - 45s - 64ms/step - accuracy: 0.8272 - loss: 0.7108 - val_accuracy: 0.8582 - val_loss: 0.6379 - learning_rate: 5.0000e-04
# Epoch 39/300
# 704/704 - 44s - 62ms/step - accuracy: 0.8286 - loss: 0.7048 - val_accuracy: 0.8472 - val_loss: 0.6542 - learning_rate: 5.0000e-04
# Epoch 40/300
# 704/704 - 45s - 64ms/step - accuracy: 0.8299 - loss: 0.7039 - val_accuracy: 0.8622 - val_loss: 0.6313 - learning_rate: 5.0000e-04
# Epoch 41/300
# 704/704 - 81s - 115ms/step - accuracy: 0.8327 - loss: 0.7015 - val_accuracy: 0.8480 - val_loss: 0.6732 - learning_rate: 5.0000e-04
# Epoch 42/300
# 704/704 - 43s - 61ms/step - accuracy: 0.8312 - loss: 0.6993 - val_accuracy: 0.8558 - val_loss: 0.6318 - learning_rate: 5.0000e-04
# Epoch 43/300
# 704/704 - 44s - 63ms/step - accuracy: 0.8335 - loss: 0.6945 - val_accuracy: 0.8576 - val_loss: 0.6284 - learning_rate: 5.0000e-04
# Epoch 44/300
# 704/704 - 44s - 62ms/step - accuracy: 0.8362 - loss: 0.6876 - val_accuracy: 0.8620 - val_loss: 0.6259 - learning_rate: 5.0000e-04
# Epoch 45/300
# 704/704 - 43s - 61ms/step - accuracy: 0.8391 - loss: 0.6823 - val_accuracy: 0.8506 - val_loss: 0.6726 - learning_rate: 5.0000e-04
# Epoch 46/300
# 704/704 - 43s - 61ms/step - accuracy: 0.8335 - loss: 0.6928 - val_accuracy: 0.8594 - val_loss: 0.6387 - learning_rate: 5.0000e-04
# Epoch 47/300
# 704/704 - 44s - 62ms/step - accuracy: 0.8360 - loss: 0.6917 - val_accuracy: 0.8630 - val_loss: 0.6297 - learning_rate: 5.0000e-04
# Epoch 48/300
# 704/704 - 43s - 62ms/step - accuracy: 0.8401 - loss: 0.6825 - val_accuracy: 0.8586 - val_loss: 0.6384 - learning_rate: 5.0000e-04
# Epoch 49/300
# 704/704 - 44s - 62ms/step - accuracy: 0.8399 - loss: 0.6760 - val_accuracy: 0.8620 - val_loss: 0.6365 - learning_rate: 5.0000e-04
# Epoch 50/300
# 704/704 - 43s - 61ms/step - accuracy: 0.8394 - loss: 0.6798 - val_accuracy: 0.8514 - val_loss: 0.6783 - learning_rate: 5.0000e-04
# Epoch 51/300
# 704/704 - 44s - 62ms/step - accuracy: 0.8407 - loss: 0.6835 - val_accuracy: 0.8458 - val_loss: 0.6843 - learning_rate: 5.0000e-04
# Epoch 52/300
# 704/704 - 44s - 63ms/step - accuracy: 0.8440 - loss: 0.6636 - val_accuracy: 0.8710 - val_loss: 0.6014 - learning_rate: 5.0000e-04
# Epoch 53/300
# 704/704 - 43s - 62ms/step - accuracy: 0.8424 - loss: 0.6704 - val_accuracy: 0.8706 - val_loss: 0.6084 - learning_rate: 5.0000e-04
# Epoch 54/300
# 704/704 - 43s - 61ms/step - accuracy: 0.8465 - loss: 0.6650 - val_accuracy: 0.8668 - val_loss: 0.6136 - learning_rate: 5.0000e-04
# Epoch 55/300
# 704/704 - 44s - 63ms/step - accuracy: 0.8458 - loss: 0.6634 - val_accuracy: 0.8542 - val_loss: 0.6643 - learning_rate: 5.0000e-04
# Epoch 56/300
# 704/704 - 43s - 62ms/step - accuracy: 0.8449 - loss: 0.6684 - val_accuracy: 0.8604 - val_loss: 0.6286 - learning_rate: 5.0000e-04
# Epoch 57/300
# 704/704 - 44s - 62ms/step - accuracy: 0.8441 - loss: 0.6687 - val_accuracy: 0.8658 - val_loss: 0.6131 - learning_rate: 5.0000e-04
# Epoch 58/300
# 704/704 - 43s - 61ms/step - accuracy: 0.8460 - loss: 0.6627 - val_accuracy: 0.8636 - val_loss: 0.6252 - learning_rate: 5.0000e-04
# Epoch 59/300
# 704/704 - 44s - 62ms/step - accuracy: 0.8462 - loss: 0.6628 - val_accuracy: 0.8720 - val_loss: 0.6060 - learning_rate: 5.0000e-04
# Epoch 60/300
# 704/704 - 44s - 63ms/step - accuracy: 0.8465 - loss: 0.6608 - val_accuracy: 0.8596 - val_loss: 0.6467 - learning_rate: 5.0000e-04
# Epoch 61/300
# 704/704 - 44s - 63ms/step - accuracy: 0.8476 - loss: 0.6565 - val_accuracy: 0.8690 - val_loss: 0.6085 - learning_rate: 5.0000e-04
# Epoch 62/300
# 704/704 - 45s - 65ms/step - accuracy: 0.8498 - loss: 0.6508 - val_accuracy: 0.8660 - val_loss: 0.6173 - learning_rate: 5.0000e-04
# Epoch 63/300
# 704/704 - 44s - 62ms/step - accuracy: 0.8639 - loss: 0.6068 - val_accuracy: 0.8812 - val_loss: 0.5627 - learning_rate: 2.5000e-04
# Epoch 64/300
# 704/704 - 45s - 63ms/step - accuracy: 0.8660 - loss: 0.5947 - val_accuracy: 0.8754 - val_loss: 0.5912 - learning_rate: 2.5000e-04
# Epoch 65/300
# 704/704 - 43s - 62ms/step - accuracy: 0.8690 - loss: 0.5786 - val_accuracy: 0.8680 - val_loss: 0.5945 - learning_rate: 2.5000e-04
# Epoch 66/300
# 704/704 - 44s - 62ms/step - accuracy: 0.8685 - loss: 0.5786 - val_accuracy: 0.8802 - val_loss: 0.5488 - learning_rate: 2.5000e-04
# Epoch 67/300
# 704/704 - 44s - 62ms/step - accuracy: 0.8724 - loss: 0.5675 - val_accuracy: 0.8790 - val_loss: 0.5623 - learning_rate: 2.5000e-04
# Epoch 68/300
# 704/704 - 45s - 65ms/step - accuracy: 0.8739 - loss: 0.5600 - val_accuracy: 0.8818 - val_loss: 0.5559 - learning_rate: 2.5000e-04
# Epoch 69/300
# 704/704 - 45s - 64ms/step - accuracy: 0.8724 - loss: 0.5607 - val_accuracy: 0.8830 - val_loss: 0.5515 - learning_rate: 2.5000e-04
# Epoch 70/300
# 704/704 - 43s - 62ms/step - accuracy: 0.8733 - loss: 0.5491 - val_accuracy: 0.8702 - val_loss: 0.5823 - learning_rate: 2.5000e-04
# Epoch 71/300
# 704/704 - 44s - 63ms/step - accuracy: 0.8753 - loss: 0.5458 - val_accuracy: 0.8838 - val_loss: 0.5524 - learning_rate: 2.5000e-04
# Epoch 72/300
# 704/704 - 44s - 62ms/step - accuracy: 0.8766 - loss: 0.5416 - val_accuracy: 0.8776 - val_loss: 0.5544 - learning_rate: 2.5000e-04
# Epoch 73/300
# 704/704 - 45s - 63ms/step - accuracy: 0.8748 - loss: 0.5419 - val_accuracy: 0.8852 - val_loss: 0.5379 - learning_rate: 2.5000e-04
# Epoch 74/300
# 704/704 - 44s - 63ms/step - accuracy: 0.8761 - loss: 0.5417 - val_accuracy: 0.8898 - val_loss: 0.5120 - learning_rate: 2.5000e-04
# Epoch 75/300
# 704/704 - 45s - 64ms/step - accuracy: 0.8784 - loss: 0.5343 - val_accuracy: 0.8842 - val_loss: 0.5373 - learning_rate: 2.5000e-04
# Epoch 76/300
# 704/704 - 45s - 64ms/step - accuracy: 0.8783 - loss: 0.5291 - val_accuracy: 0.8910 - val_loss: 0.5189 - learning_rate: 2.5000e-04
# Epoch 77/300
# 704/704 - 80s - 114ms/step - accuracy: 0.8790 - loss: 0.5253 - val_accuracy: 0.8770 - val_loss: 0.5714 - learning_rate: 2.5000e-04
# Epoch 78/300
# 704/704 - 83s - 117ms/step - accuracy: 0.8786 - loss: 0.5291 - val_accuracy: 0.8866 - val_loss: 0.5220 - learning_rate: 2.5000e-04
# Epoch 79/300
# 704/704 - 44s - 63ms/step - accuracy: 0.8780 - loss: 0.5279 - val_accuracy: 0.8778 - val_loss: 0.5373 - learning_rate: 2.5000e-04
# Epoch 80/300
# 704/704 - 43s - 60ms/step - accuracy: 0.8782 - loss: 0.5217 - val_accuracy: 0.8760 - val_loss: 0.5619 - learning_rate: 2.5000e-04
# Epoch 81/300
# 704/704 - 44s - 62ms/step - accuracy: 0.8804 - loss: 0.5181 - val_accuracy: 0.8836 - val_loss: 0.5232 - learning_rate: 2.5000e-04
# Epoch 82/300
# 704/704 - 43s - 61ms/step - accuracy: 0.8804 - loss: 0.5175 - val_accuracy: 0.8846 - val_loss: 0.5210 - learning_rate: 2.5000e-04
# Epoch 83/300
# 704/704 - 43s - 61ms/step - accuracy: 0.8801 - loss: 0.5163 - val_accuracy: 0.8908 - val_loss: 0.5041 - learning_rate: 2.5000e-04
# Epoch 84/300
# 704/704 - 44s - 62ms/step - accuracy: 0.8806 - loss: 0.5145 - val_accuracy: 0.8806 - val_loss: 0.5330 - learning_rate: 2.5000e-04
# Epoch 85/300
# 704/704 - 43s - 61ms/step - accuracy: 0.8794 - loss: 0.5156 - val_accuracy: 0.8868 - val_loss: 0.5315 - learning_rate: 2.5000e-04
# Epoch 86/300
# 704/704 - 42s - 60ms/step - accuracy: 0.8809 - loss: 0.5122 - val_accuracy: 0.8860 - val_loss: 0.5159 - learning_rate: 2.5000e-04
# Epoch 87/300
# 704/704 - 43s - 61ms/step - accuracy: 0.8827 - loss: 0.5038 - val_accuracy: 0.8882 - val_loss: 0.5174 - learning_rate: 2.5000e-04
# Epoch 88/300
# 704/704 - 82s - 116ms/step - accuracy: 0.8808 - loss: 0.5093 - val_accuracy: 0.8858 - val_loss: 0.5171 - learning_rate: 2.5000e-04
# Epoch 89/300
# 704/704 - 43s - 61ms/step - accuracy: 0.8823 - loss: 0.5081 - val_accuracy: 0.8878 - val_loss: 0.5164 - learning_rate: 2.5000e-04
# Epoch 90/300
# 704/704 - 43s - 62ms/step - accuracy: 0.8814 - loss: 0.5059 - val_accuracy: 0.8920 - val_loss: 0.4964 - learning_rate: 2.5000e-04
# Epoch 91/300
# 704/704 - 43s - 61ms/step - accuracy: 0.8842 - loss: 0.5019 - val_accuracy: 0.8834 - val_loss: 0.5160 - learning_rate: 2.5000e-04
# Epoch 92/300
# 704/704 - 43s - 61ms/step - accuracy: 0.8858 - loss: 0.4971 - val_accuracy: 0.8834 - val_loss: 0.5273 - learning_rate: 2.5000e-04
# Epoch 93/300
# 704/704 - 43s - 61ms/step - accuracy: 0.8857 - loss: 0.4973 - val_accuracy: 0.8908 - val_loss: 0.4994 - learning_rate: 2.5000e-04
# Epoch 94/300
# 704/704 - 43s - 60ms/step - accuracy: 0.8846 - loss: 0.4958 - val_accuracy: 0.8872 - val_loss: 0.4997 - learning_rate: 2.5000e-04
# Epoch 95/300
# 704/704 - 43s - 61ms/step - accuracy: 0.8827 - loss: 0.5035 - val_accuracy: 0.8862 - val_loss: 0.5060 - learning_rate: 2.5000e-04
# Epoch 96/300
# 704/704 - 44s - 62ms/step - accuracy: 0.8840 - loss: 0.4972 - val_accuracy: 0.8874 - val_loss: 0.5030 - learning_rate: 2.5000e-04
# Epoch 97/300
# 704/704 - 43s - 62ms/step - accuracy: 0.8833 - loss: 0.4986 - val_accuracy: 0.8940 - val_loss: 0.4906 - learning_rate: 2.5000e-04
# Epoch 98/300
# 704/704 - 44s - 63ms/step - accuracy: 0.8859 - loss: 0.4900 - val_accuracy: 0.8880 - val_loss: 0.4947 - learning_rate: 2.5000e-04
# Epoch 99/300
# 704/704 - 43s - 61ms/step - accuracy: 0.8858 - loss: 0.4901 - val_accuracy: 0.8892 - val_loss: 0.5000 - learning_rate: 2.5000e-04
# Epoch 100/300
# 704/704 - 44s - 62ms/step - accuracy: 0.8817 - loss: 0.4997 - val_accuracy: 0.8856 - val_loss: 0.5178 - learning_rate: 2.5000e-04
# Epoch 101/300
# 704/704 - 45s - 63ms/step - accuracy: 0.8860 - loss: 0.4917 - val_accuracy: 0.8930 - val_loss: 0.4742 - learning_rate: 2.5000e-04
# Epoch 102/300
# 704/704 - 44s - 62ms/step - accuracy: 0.8871 - loss: 0.4844 - val_accuracy: 0.8862 - val_loss: 0.5110 - learning_rate: 2.5000e-04
# Epoch 103/300
# 704/704 - 82s - 116ms/step - accuracy: 0.8879 - loss: 0.4854 - val_accuracy: 0.8836 - val_loss: 0.5341 - learning_rate: 2.5000e-04
# Epoch 104/300
# 704/704 - 43s - 61ms/step - accuracy: 0.8870 - loss: 0.4876 - val_accuracy: 0.9004 - val_loss: 0.4616 - learning_rate: 2.5000e-04
# Epoch 105/300
# 704/704 - 44s - 62ms/step - accuracy: 0.8876 - loss: 0.4844 - val_accuracy: 0.8856 - val_loss: 0.5108 - learning_rate: 2.5000e-04
# Epoch 106/300
# 704/704 - 43s - 60ms/step - accuracy: 0.8868 - loss: 0.4876 - val_accuracy: 0.8874 - val_loss: 0.5109 - learning_rate: 2.5000e-04
# Epoch 107/300
# 704/704 - 44s - 62ms/step - accuracy: 0.8879 - loss: 0.4836 - val_accuracy: 0.8888 - val_loss: 0.4977 - learning_rate: 2.5000e-04
# Epoch 108/300
# 704/704 - 43s - 62ms/step - accuracy: 0.8861 - loss: 0.4862 - val_accuracy: 0.8922 - val_loss: 0.4867 - learning_rate: 2.5000e-04
# Epoch 109/300
# 704/704 - 45s - 64ms/step - accuracy: 0.8890 - loss: 0.4827 - val_accuracy: 0.8800 - val_loss: 0.5236 - learning_rate: 2.5000e-04
# Epoch 110/300
# 704/704 - 81s - 115ms/step - accuracy: 0.8863 - loss: 0.4846 - val_accuracy: 0.8842 - val_loss: 0.5089 - learning_rate: 2.5000e-04
# Epoch 111/300
# 704/704 - 82s - 117ms/step - accuracy: 0.8886 - loss: 0.4795 - val_accuracy: 0.8874 - val_loss: 0.5028 - learning_rate: 2.5000e-04
# Epoch 112/300
# 704/704 - 44s - 62ms/step - accuracy: 0.8893 - loss: 0.4785 - val_accuracy: 0.8724 - val_loss: 0.5529 - learning_rate: 2.5000e-04
# Epoch 113/300
# 704/704 - 44s - 63ms/step - accuracy: 0.8870 - loss: 0.4831 - val_accuracy: 0.9004 - val_loss: 0.4580 - learning_rate: 2.5000e-04
# Epoch 114/300
# 704/704 - 43s - 61ms/step - accuracy: 0.8884 - loss: 0.4834 - val_accuracy: 0.8836 - val_loss: 0.5353 - learning_rate: 2.5000e-04
# Epoch 115/300
# 704/704 - 82s - 117ms/step - accuracy: 0.8900 - loss: 0.4811 - val_accuracy: 0.8906 - val_loss: 0.5107 - learning_rate: 2.5000e-04
# Epoch 116/300
# 704/704 - 44s - 63ms/step - accuracy: 0.8878 - loss: 0.4794 - val_accuracy: 0.8900 - val_loss: 0.4884 - learning_rate: 2.5000e-04
# Epoch 117/300
# 704/704 - 43s - 61ms/step - accuracy: 0.8908 - loss: 0.4750 - val_accuracy: 0.8930 - val_loss: 0.4884 - learning_rate: 2.5000e-04
# Epoch 118/300
# 704/704 - 43s - 62ms/step - accuracy: 0.8901 - loss: 0.4756 - val_accuracy: 0.8882 - val_loss: 0.4956 - learning_rate: 2.5000e-04
# Epoch 119/300
# 704/704 - 42s - 60ms/step - accuracy: 0.8886 - loss: 0.4768 - val_accuracy: 0.8996 - val_loss: 0.4674 - learning_rate: 2.5000e-04
# Epoch 120/300
# 704/704 - 42s - 60ms/step - accuracy: 0.8903 - loss: 0.4764 - val_accuracy: 0.8902 - val_loss: 0.5001 - learning_rate: 2.5000e-04
# Epoch 121/300
# 704/704 - 42s - 60ms/step - accuracy: 0.8893 - loss: 0.4758 - val_accuracy: 0.8898 - val_loss: 0.5046 - learning_rate: 2.5000e-04
# Epoch 122/300
# 704/704 - 42s - 59ms/step - accuracy: 0.8887 - loss: 0.4766 - val_accuracy: 0.8894 - val_loss: 0.5008 - learning_rate: 2.5000e-04
# Epoch 123/300
# 704/704 - 43s - 61ms/step - accuracy: 0.8910 - loss: 0.4719 - val_accuracy: 0.8912 - val_loss: 0.4901 - learning_rate: 2.5000e-04
# Epoch 124/300
# 704/704 - 43s - 60ms/step - accuracy: 0.9004 - loss: 0.4511 - val_accuracy: 0.8968 - val_loss: 0.4719 - learning_rate: 1.2500e-04
# Epoch 125/300
# 704/704 - 45s - 63ms/step - accuracy: 0.8999 - loss: 0.4451 - val_accuracy: 0.9022 - val_loss: 0.4563 - learning_rate: 1.2500e-04
# Epoch 126/300
# 704/704 - 44s - 62ms/step - accuracy: 0.9039 - loss: 0.4346 - val_accuracy: 0.8950 - val_loss: 0.4778 - learning_rate: 1.2500e-04
# Epoch 127/300
# 704/704 - 45s - 64ms/step - accuracy: 0.9020 - loss: 0.4358 - val_accuracy: 0.9034 - val_loss: 0.4463 - learning_rate: 1.2500e-04
# Epoch 128/300
# 704/704 - 43s - 61ms/step - accuracy: 0.9029 - loss: 0.4311 - val_accuracy: 0.9024 - val_loss: 0.4591 - learning_rate: 1.2500e-04
# Epoch 129/300
# 704/704 - 43s - 62ms/step - accuracy: 0.9045 - loss: 0.4247 - val_accuracy: 0.8968 - val_loss: 0.4732 - learning_rate: 1.2500e-04
# Epoch 130/300
# 704/704 - 43s - 61ms/step - accuracy: 0.9040 - loss: 0.4232 - val_accuracy: 0.8980 - val_loss: 0.4693 - learning_rate: 1.2500e-04
# Epoch 131/300
# 704/704 - 44s - 63ms/step - accuracy: 0.9033 - loss: 0.4240 - val_accuracy: 0.9010 - val_loss: 0.4524 - learning_rate: 1.2500e-04
# Epoch 132/300
# 704/704 - 43s - 61ms/step - accuracy: 0.9037 - loss: 0.4211 - val_accuracy: 0.8990 - val_loss: 0.4700 - learning_rate: 1.2500e-04
# Epoch 133/300
# 704/704 - 44s - 63ms/step - accuracy: 0.9062 - loss: 0.4176 - val_accuracy: 0.9006 - val_loss: 0.4513 - learning_rate: 1.2500e-04
# Epoch 134/300
# 704/704 - 42s - 60ms/step - accuracy: 0.9056 - loss: 0.4189 - val_accuracy: 0.8992 - val_loss: 0.4593 - learning_rate: 1.2500e-04
# Epoch 135/300
# 704/704 - 43s - 62ms/step - accuracy: 0.9062 - loss: 0.4173 - val_accuracy: 0.8946 - val_loss: 0.4906 - learning_rate: 1.2500e-04
# Epoch 136/300
# 704/704 - 43s - 61ms/step - accuracy: 0.9081 - loss: 0.4118 - val_accuracy: 0.8980 - val_loss: 0.4586 - learning_rate: 1.2500e-04
# Epoch 137/300
# 704/704 - 43s - 62ms/step - accuracy: 0.9077 - loss: 0.4093 - val_accuracy: 0.8990 - val_loss: 0.4551 - learning_rate: 1.2500e-04
# Epoch 138/300
# 704/704 - 43s - 61ms/step - accuracy: 0.9114 - loss: 0.4002 - val_accuracy: 0.9000 - val_loss: 0.4577 - learning_rate: 6.2500e-05
# Epoch 139/300
# 704/704 - 81s - 116ms/step - accuracy: 0.9137 - loss: 0.3906 - val_accuracy: 0.9022 - val_loss: 0.4479 - learning_rate: 6.2500e-05
# Epoch 140/300
# 704/704 - 43s - 61ms/step - accuracy: 0.9141 - loss: 0.3888 - val_accuracy: 0.9032 - val_loss: 0.4443 - learning_rate: 6.2500e-05
# Epoch 141/300
# 704/704 - 44s - 62ms/step - accuracy: 0.9130 - loss: 0.3910 - val_accuracy: 0.9052 - val_loss: 0.4424 - learning_rate: 6.2500e-05
# Epoch 142/300
# 704/704 - 44s - 62ms/step - accuracy: 0.9148 - loss: 0.3852 - val_accuracy: 0.9034 - val_loss: 0.4517 - learning_rate: 6.2500e-05
# Epoch 143/300
# 704/704 - 42s - 60ms/step - accuracy: 0.9151 - loss: 0.3819 - val_accuracy: 0.9062 - val_loss: 0.4455 - learning_rate: 6.2500e-05
# Epoch 144/300
# 704/704 - 44s - 62ms/step - accuracy: 0.9139 - loss: 0.3847 - val_accuracy: 0.9030 - val_loss: 0.4522 - learning_rate: 6.2500e-05
# Epoch 145/300
# 704/704 - 43s - 61ms/step - accuracy: 0.9148 - loss: 0.3825 - val_accuracy: 0.9044 - val_loss: 0.4366 - learning_rate: 6.2500e-05
# Epoch 146/300
# 704/704 - 43s - 60ms/step - accuracy: 0.9160 - loss: 0.3780 - val_accuracy: 0.9010 - val_loss: 0.4549 - learning_rate: 6.2500e-05
# Epoch 147/300
# 704/704 - 42s - 59ms/step - accuracy: 0.9158 - loss: 0.3773 - val_accuracy: 0.9058 - val_loss: 0.4503 - learning_rate: 6.2500e-05
# Epoch 148/300
# 704/704 - 42s - 59ms/step - accuracy: 0.9141 - loss: 0.3787 - val_accuracy: 0.9018 - val_loss: 0.4525 - learning_rate: 6.2500e-05
# Epoch 149/300
# 704/704 - 44s - 62ms/step - accuracy: 0.9145 - loss: 0.3767 - val_accuracy: 0.9016 - val_loss: 0.4583 - learning_rate: 6.2500e-05
# Epoch 150/300
# 704/704 - 42s - 60ms/step - accuracy: 0.9170 - loss: 0.3730 - val_accuracy: 0.9044 - val_loss: 0.4392 - learning_rate: 6.2500e-05
# Epoch 151/300
# 704/704 - 43s - 61ms/step - accuracy: 0.9182 - loss: 0.3688 - val_accuracy: 0.9062 - val_loss: 0.4318 - learning_rate: 6.2500e-05
# Epoch 152/300
# 704/704 - 43s - 60ms/step - accuracy: 0.9162 - loss: 0.3701 - val_accuracy: 0.9024 - val_loss: 0.4435 - learning_rate: 6.2500e-05
# Epoch 153/300
# 704/704 - 43s - 61ms/step - accuracy: 0.9182 - loss: 0.3691 - val_accuracy: 0.9060 - val_loss: 0.4442 - learning_rate: 6.2500e-05
# Epoch 154/300
# 704/704 - 42s - 59ms/step - accuracy: 0.9197 - loss: 0.3679 - val_accuracy: 0.9060 - val_loss: 0.4363 - learning_rate: 6.2500e-05
# Epoch 155/300
# 704/704 - 43s - 61ms/step - accuracy: 0.9182 - loss: 0.3668 - val_accuracy: 0.9074 - val_loss: 0.4365 - learning_rate: 6.2500e-05
# Epoch 156/300
# 704/704 - 82s - 117ms/step - accuracy: 0.9170 - loss: 0.3670 - val_accuracy: 0.9050 - val_loss: 0.4322 - learning_rate: 6.2500e-05
# Epoch 157/300
# 704/704 - 83s - 118ms/step - accuracy: 0.9207 - loss: 0.3605 - val_accuracy: 0.9046 - val_loss: 0.4395 - learning_rate: 6.2500e-05
# Epoch 158/300
# 704/704 - 80s - 114ms/step - accuracy: 0.9193 - loss: 0.3642 - val_accuracy: 0.9032 - val_loss: 0.4498 - learning_rate: 6.2500e-05
# Epoch 159/300
# 704/704 - 44s - 62ms/step - accuracy: 0.9185 - loss: 0.3629 - val_accuracy: 0.9068 - val_loss: 0.4327 - learning_rate: 6.2500e-05
# Epoch 160/300
# 704/704 - 43s - 61ms/step - accuracy: 0.9196 - loss: 0.3623 - val_accuracy: 0.9074 - val_loss: 0.4334 - learning_rate: 6.2500e-05
# Epoch 161/300
# 704/704 - 44s - 62ms/step - accuracy: 0.9186 - loss: 0.3591 - val_accuracy: 0.9032 - val_loss: 0.4496 - learning_rate: 6.2500e-05
# Epoch 162/300
# 704/704 - 43s - 60ms/step - accuracy: 0.9202 - loss: 0.3568 - val_accuracy: 0.9074 - val_loss: 0.4273 - learning_rate: 3.1250e-05
# Epoch 163/300
# 704/704 - 43s - 61ms/step - accuracy: 0.9237 - loss: 0.3521 - val_accuracy: 0.9062 - val_loss: 0.4341 - learning_rate: 3.1250e-05
# Epoch 164/300
# 704/704 - 82s - 117ms/step - accuracy: 0.9222 - loss: 0.3531 - val_accuracy: 0.9084 - val_loss: 0.4295 - learning_rate: 3.1250e-05
# Epoch 165/300
# 704/704 - 43s - 61ms/step - accuracy: 0.9243 - loss: 0.3491 - val_accuracy: 0.9072 - val_loss: 0.4294 - learning_rate: 3.1250e-05
# Epoch 166/300
# 704/704 - 42s - 60ms/step - accuracy: 0.9228 - loss: 0.3483 - val_accuracy: 0.9046 - val_loss: 0.4391 - learning_rate: 3.1250e-05
# Epoch 167/300
# 704/704 - 42s - 60ms/step - accuracy: 0.9234 - loss: 0.3460 - val_accuracy: 0.9052 - val_loss: 0.4301 - learning_rate: 3.1250e-05
# Epoch 168/300
# 704/704 - 42s - 59ms/step - accuracy: 0.9236 - loss: 0.3456 - val_accuracy: 0.9076 - val_loss: 0.4288 - learning_rate: 3.1250e-05
# Epoch 169/300
# 704/704 - 43s - 61ms/step - accuracy: 0.9231 - loss: 0.3465 - val_accuracy: 0.9052 - val_loss: 0.4277 - learning_rate: 3.1250e-05
# Epoch 170/300
# 704/704 - 41s - 59ms/step - accuracy: 0.9217 - loss: 0.3479 - val_accuracy: 0.9094 - val_loss: 0.4154 - learning_rate: 3.1250e-05
# Epoch 171/300
# 704/704 - 42s - 60ms/step - accuracy: 0.9249 - loss: 0.3427 - val_accuracy: 0.9092 - val_loss: 0.4195 - learning_rate: 3.1250e-05
# Epoch 172/300
# 704/704 - 81s - 115ms/step - accuracy: 0.9254 - loss: 0.3423 - val_accuracy: 0.9070 - val_loss: 0.4202 - learning_rate: 3.1250e-05
# Epoch 173/300
# 704/704 - 42s - 60ms/step - accuracy: 0.9244 - loss: 0.3404 - val_accuracy: 0.9060 - val_loss: 0.4242 - learning_rate: 3.1250e-05
# Epoch 174/300
# 704/704 - 42s - 60ms/step - accuracy: 0.9226 - loss: 0.3459 - val_accuracy: 0.9076 - val_loss: 0.4227 - learning_rate: 3.1250e-05
# Epoch 175/300
# 704/704 - 42s - 60ms/step - accuracy: 0.9247 - loss: 0.3379 - val_accuracy: 0.9074 - val_loss: 0.4324 - learning_rate: 3.1250e-05
# Epoch 176/300
# 704/704 - 41s - 59ms/step - accuracy: 0.9229 - loss: 0.3397 - val_accuracy: 0.9062 - val_loss: 0.4262 - learning_rate: 3.1250e-05
# Epoch 177/300
# 704/704 - 42s - 60ms/step - accuracy: 0.9252 - loss: 0.3385 - val_accuracy: 0.9056 - val_loss: 0.4268 - learning_rate: 3.1250e-05
# Epoch 178/300
# 704/704 - 42s - 60ms/step - accuracy: 0.9251 - loss: 0.3421 - val_accuracy: 0.9052 - val_loss: 0.4278 - learning_rate: 3.1250e-05
# Epoch 179/300
# 704/704 - 82s - 117ms/step - accuracy: 0.9242 - loss: 0.3386 - val_accuracy: 0.9090 - val_loss: 0.4173 - learning_rate: 3.1250e-05
# Epoch 180/300
# 704/704 - 42s - 60ms/step - accuracy: 0.9255 - loss: 0.3369 - val_accuracy: 0.9074 - val_loss: 0.4204 - learning_rate: 3.1250e-05
# Epoch 181/300
# 704/704 - 44s - 62ms/step - accuracy: 0.9269 - loss: 0.3329 - val_accuracy: 0.9068 - val_loss: 0.4218 - learning_rate: 1.5625e-05
# Epoch 182/300
# 704/704 - 44s - 63ms/step - accuracy: 0.9247 - loss: 0.3386 - val_accuracy: 0.9086 - val_loss: 0.4235 - learning_rate: 1.5625e-05
# Epoch 183/300
# 704/704 - 43s - 61ms/step - accuracy: 0.9264 - loss: 0.3315 - val_accuracy: 0.9094 - val_loss: 0.4175 - learning_rate: 1.5625e-05
# Epoch 184/300
# 704/704 - 42s - 60ms/step - accuracy: 0.9268 - loss: 0.3325 - val_accuracy: 0.9088 - val_loss: 0.4239 - learning_rate: 1.5625e-05
# Epoch 185/300
# 704/704 - 44s - 63ms/step - accuracy: 0.9264 - loss: 0.3338 - val_accuracy: 0.9092 - val_loss: 0.4162 - learning_rate: 1.5625e-05
# Epoch 186/300
# 704/704 - 43s - 61ms/step - accuracy: 0.9265 - loss: 0.3325 - val_accuracy: 0.9072 - val_loss: 0.4236 - learning_rate: 1.5625e-05
# Epoch 187/300
# 704/704 - 82s - 117ms/step - accuracy: 0.9272 - loss: 0.3318 - val_accuracy: 0.9098 - val_loss: 0.4183 - learning_rate: 1.5625e-05
# Epoch 188/300
# 704/704 - 44s - 62ms/step - accuracy: 0.9297 - loss: 0.3278 - val_accuracy: 0.9102 - val_loss: 0.4149 - learning_rate: 1.5625e-05
# Epoch 189/300
# 704/704 - 43s - 61ms/step - accuracy: 0.9290 - loss: 0.3278 - val_accuracy: 0.9096 - val_loss: 0.4183 - learning_rate: 1.5625e-05
# Epoch 190/300
# 704/704 - 45s - 63ms/step - accuracy: 0.9286 - loss: 0.3299 - val_accuracy: 0.9100 - val_loss: 0.4168 - learning_rate: 1.5625e-05
# Epoch 191/300
# 704/704 - 43s - 61ms/step - accuracy: 0.9294 - loss: 0.3244 - val_accuracy: 0.9096 - val_loss: 0.4165 - learning_rate: 1.5625e-05
# Epoch 192/300
# 704/704 - 43s - 62ms/step - accuracy: 0.9302 - loss: 0.3244 - val_accuracy: 0.9066 - val_loss: 0.4217 - learning_rate: 1.5625e-05
# Epoch 193/300
# 704/704 - 44s - 62ms/step - accuracy: 0.9289 - loss: 0.3262 - val_accuracy: 0.9106 - val_loss: 0.4141 - learning_rate: 1.5625e-05
# Epoch 194/300
# 704/704 - 44s - 62ms/step - accuracy: 0.9282 - loss: 0.3277 - val_accuracy: 0.9074 - val_loss: 0.4179 - learning_rate: 1.5625e-05
# Epoch 195/300
# 704/704 - 43s - 61ms/step - accuracy: 0.9286 - loss: 0.3262 - val_accuracy: 0.9084 - val_loss: 0.4190 - learning_rate: 1.5625e-05
# Epoch 196/300
# 704/704 - 44s - 63ms/step - accuracy: 0.9270 - loss: 0.3291 - val_accuracy: 0.9102 - val_loss: 0.4161 - learning_rate: 1.5625e-05
# Epoch 197/300
# 704/704 - 44s - 63ms/step - accuracy: 0.9271 - loss: 0.3286 - val_accuracy: 0.9078 - val_loss: 0.4204 - learning_rate: 1.5625e-05
# Epoch 198/300
# 704/704 - 81s - 115ms/step - accuracy: 0.9280 - loss: 0.3284 - val_accuracy: 0.9084 - val_loss: 0.4157 - learning_rate: 1.5625e-05
# Epoch 199/300
# 704/704 - 44s - 62ms/step - accuracy: 0.9284 - loss: 0.3257 - val_accuracy: 0.9086 - val_loss: 0.4171 - learning_rate: 1.5625e-05
# Epoch 200/300
# 704/704 - 43s - 61ms/step - accuracy: 0.9278 - loss: 0.3277 - val_accuracy: 0.9090 - val_loss: 0.4168 - learning_rate: 1.5625e-05
# Epoch 201/300
# 704/704 - 43s - 62ms/step - accuracy: 0.9316 - loss: 0.3203 - val_accuracy: 0.9080 - val_loss: 0.4176 - learning_rate: 1.5625e-05
# Epoch 202/300
# 704/704 - 42s - 60ms/step - accuracy: 0.9283 - loss: 0.3264 - val_accuracy: 0.9074 - val_loss: 0.4189 - learning_rate: 1.5625e-05
# Epoch 203/300
# 704/704 - 43s - 61ms/step - accuracy: 0.9288 - loss: 0.3250 - val_accuracy: 0.9086 - val_loss: 0.4166 - learning_rate: 1.5625e-05
# Epoch 204/300
# 704/704 - 43s - 61ms/step - accuracy: 0.9280 - loss: 0.3250 - val_accuracy: 0.9092 - val_loss: 0.4161 - learning_rate: 1.0000e-05
# Epoch 205/300
# 704/704 - 43s - 61ms/step - accuracy: 0.9294 - loss: 0.3210 - val_accuracy: 0.9092 - val_loss: 0.4213 - learning_rate: 1.0000e-05
# Epoch 206/300
# 704/704 - 43s - 60ms/step - accuracy: 0.9305 - loss: 0.3202 - val_accuracy: 0.9092 - val_loss: 0.4216 - learning_rate: 1.0000e-05
# Epoch 207/300
# 704/704 - 44s - 63ms/step - accuracy: 0.9300 - loss: 0.3238 - val_accuracy: 0.9076 - val_loss: 0.4188 - learning_rate: 1.0000e-05
# Epoch 208/300
# 704/704 - 43s - 61ms/step - accuracy: 0.9309 - loss: 0.3190 - val_accuracy: 0.9090 - val_loss: 0.4202 - learning_rate: 1.0000e-05
# Epoch 209/300
# 704/704 - 44s - 62ms/step - accuracy: 0.9307 - loss: 0.3194 - val_accuracy: 0.9086 - val_loss: 0.4160 - learning_rate: 1.0000e-05
# Epoch 210/300
# 704/704 - 42s - 60ms/step - accuracy: 0.9314 - loss: 0.3176 - val_accuracy: 0.9096 - val_loss: 0.4174 - learning_rate: 1.0000e-05
# Epoch 211/300
# 704/704 - 43s - 61ms/step - accuracy: 0.9302 - loss: 0.3188 - val_accuracy: 0.9076 - val_loss: 0.4203 - learning_rate: 1.0000e-05
# Epoch 212/300
# 704/704 - 42s - 59ms/step - accuracy: 0.9288 - loss: 0.3227 - val_accuracy: 0.9082 - val_loss: 0.4188 - learning_rate: 1.0000e-05
# Epoch 213/300
# 704/704 - 84s - 119ms/step - accuracy: 0.9302 - loss: 0.3157 - val_accuracy: 0.9074 - val_loss: 0.4206 - learning_rate: 1.0000e-05
# Epoch 214/300
# 704/704 - 44s - 63ms/step - accuracy: 0.9280 - loss: 0.3220 - val_accuracy: 0.9074 - val_loss: 0.4194 - learning_rate: 1.0000e-05
# Epoch 215/300
# 704/704 - 43s - 61ms/step - accuracy: 0.9299 - loss: 0.3196 - val_accuracy: 0.9094 - val_loss: 0.4116 - learning_rate: 1.0000e-05
# Epoch 216/300
# 704/704 - 44s - 63ms/step - accuracy: 0.9310 - loss: 0.3202 - val_accuracy: 0.9086 - val_loss: 0.4135 - learning_rate: 1.0000e-05
# Epoch 217/300
# 704/704 - 45s - 63ms/step - accuracy: 0.9294 - loss: 0.3202 - val_accuracy: 0.9090 - val_loss: 0.4177 - learning_rate: 1.0000e-05
# Epoch 218/300
# 704/704 - 44s - 63ms/step - accuracy: 0.9298 - loss: 0.3169 - val_accuracy: 0.9082 - val_loss: 0.4182 - learning_rate: 1.0000e-05
# Epoch 219/300
# 704/704 - 44s - 63ms/step - accuracy: 0.9310 - loss: 0.3165 - val_accuracy: 0.9088 - val_loss: 0.4183 - learning_rate: 1.0000e-05
# Epoch 220/300
# 704/704 - 81s - 115ms/step - accuracy: 0.9306 - loss: 0.3145 - val_accuracy: 0.9086 - val_loss: 0.4159 - learning_rate: 1.0000e-05
# Epoch 221/300
# 704/704 - 44s - 62ms/step - accuracy: 0.9317 - loss: 0.3168 - val_accuracy: 0.9084 - val_loss: 0.4181 - learning_rate: 1.0000e-05
# Epoch 222/300
# 704/704 - 44s - 62ms/step - accuracy: 0.9316 - loss: 0.3137 - val_accuracy: 0.9084 - val_loss: 0.4147 - learning_rate: 1.0000e-05
# Epoch 223/300
# 704/704 - 45s - 63ms/step - accuracy: 0.9305 - loss: 0.3189 - val_accuracy: 0.9088 - val_loss: 0.4194 - learning_rate: 1.0000e-05
# Epoch 224/300
# 704/704 - 44s - 62ms/step - accuracy: 0.9296 - loss: 0.3202 - val_accuracy: 0.9080 - val_loss: 0.4185 - learning_rate: 1.0000e-05
# Epoch 225/300
# 704/704 - 45s - 64ms/step - accuracy: 0.9306 - loss: 0.3181 - val_accuracy: 0.9112 - val_loss: 0.4133 - learning_rate: 1.0000e-05
# Epoch 226/300
# 704/704 - 45s - 64ms/step - accuracy: 0.9314 - loss: 0.3170 - val_accuracy: 0.9102 - val_loss: 0.4194 - learning_rate: 1.0000e-05
# Epoch 227/300
# 704/704 - 44s - 62ms/step - accuracy: 0.9318 - loss: 0.3152 - val_accuracy: 0.9086 - val_loss: 0.4167 - learning_rate: 1.0000e-05
# Epoch 228/300
# 704/704 - 44s - 62ms/step - accuracy: 0.9320 - loss: 0.3149 - val_accuracy: 0.9098 - val_loss: 0.4156 - learning_rate: 1.0000e-05
# Epoch 229/300
# 704/704 - 44s - 62ms/step - accuracy: 0.9316 - loss: 0.3157 - val_accuracy: 0.9098 - val_loss: 0.4172 - learning_rate: 1.0000e-05
# Epoch 230/300
# 704/704 - 45s - 64ms/step - accuracy: 0.9307 - loss: 0.3157 - val_accuracy: 0.9100 - val_loss: 0.4145 - learning_rate: 1.0000e-05
# Epoch 231/300
# 704/704 - 46s - 66ms/step - accuracy: 0.9314 - loss: 0.3125 - val_accuracy: 0.9104 - val_loss: 0.4147 - learning_rate: 1.0000e-05
# Epoch 232/300
# 704/704 - 45s - 64ms/step - accuracy: 0.9297 - loss: 0.3151 - val_accuracy: 0.9102 - val_loss: 0.4161 - learning_rate: 1.0000e-05
# Epoch 233/300
# 704/704 - 46s - 65ms/step - accuracy: 0.9312 - loss: 0.3125 - val_accuracy: 0.9102 - val_loss: 0.4182 - learning_rate: 1.0000e-05
# Epoch 234/300
# 704/704 - 45s - 64ms/step - accuracy: 0.9314 - loss: 0.3132 - val_accuracy: 0.9096 - val_loss: 0.4225 - learning_rate: 1.0000e-05
# Epoch 235/300
# 704/704 - 45s - 64ms/step - accuracy: 0.9306 - loss: 0.3168 - val_accuracy: 0.9094 - val_loss: 0.4206 - learning_rate: 1.0000e-05
# Epoch 236/300
# 704/704 - 45s - 64ms/step - accuracy: 0.9330 - loss: 0.3120 - val_accuracy: 0.9084 - val_loss: 0.4194 - learning_rate: 1.0000e-05
# Epoch 237/300
# 704/704 - 44s - 63ms/step - accuracy: 0.9310 - loss: 0.3161 - val_accuracy: 0.9098 - val_loss: 0.4155 - learning_rate: 1.0000e-05
# Epoch 238/300
# 704/704 - 45s - 64ms/step - accuracy: 0.9311 - loss: 0.3146 - val_accuracy: 0.9090 - val_loss: 0.4219 - learning_rate: 1.0000e-05
# Epoch 239/300
# 704/704 - 47s - 66ms/step - accuracy: 0.9320 - loss: 0.3108 - val_accuracy: 0.9100 - val_loss: 0.4178 - learning_rate: 1.0000e-05
# Epoch 240/300
# 704/704 - 45s - 64ms/step - accuracy: 0.9320 - loss: 0.3124 - val_accuracy: 0.9100 - val_loss: 0.4174 - learning_rate: 1.0000e-05
# Epoch 241/300
# 704/704 - 45s - 65ms/step - accuracy: 0.9315 - loss: 0.3130 - val_accuracy: 0.9104 - val_loss: 0.4125 - learning_rate: 1.0000e-05
# Epoch 242/300
# 704/704 - 45s - 64ms/step - accuracy: 0.9324 - loss: 0.3125 - val_accuracy: 0.9112 - val_loss: 0.4146 - learning_rate: 1.0000e-05
# Epoch 243/300
# 704/704 - 45s - 64ms/step - accuracy: 0.9296 - loss: 0.3160 - val_accuracy: 0.9090 - val_loss: 0.4170 - learning_rate: 1.0000e-05
# Epoch 244/300
# 704/704 - 45s - 64ms/step - accuracy: 0.9326 - loss: 0.3099 - val_accuracy: 0.9084 - val_loss: 0.4194 - learning_rate: 1.0000e-05
# Epoch 245/300
# 704/704 - 44s - 63ms/step - accuracy: 0.9321 - loss: 0.3126 - val_accuracy: 0.9092 - val_loss: 0.4136 - learning_rate: 1.0000e-05
# Epoch 246/300
# 704/704 - 45s - 64ms/step - accuracy: 0.9324 - loss: 0.3129 - val_accuracy: 0.9086 - val_loss: 0.4158 - learning_rate: 1.0000e-05
# Epoch 247/300
# 704/704 - 46s - 66ms/step - accuracy: 0.9326 - loss: 0.3104 - val_accuracy: 0.9066 - val_loss: 0.4257 - learning_rate: 1.0000e-05
# Epoch 248/300
# 704/704 - 45s - 63ms/step - accuracy: 0.9342 - loss: 0.3067 - val_accuracy: 0.9070 - val_loss: 0.4158 - learning_rate: 1.0000e-05
# Epoch 249/300
# 704/704 - 45s - 65ms/step - accuracy: 0.9323 - loss: 0.3093 - val_accuracy: 0.9080 - val_loss: 0.4154 - learning_rate: 1.0000e-05
# Epoch 250/300
# 704/704 - 44s - 63ms/step - accuracy: 0.9326 - loss: 0.3085 - val_accuracy: 0.9092 - val_loss: 0.4209 - learning_rate: 1.0000e-05
# Epoch 251/300
# 704/704 - 81s - 115ms/step - accuracy: 0.9323 - loss: 0.3113 - val_accuracy: 0.9084 - val_loss: 0.4236 - learning_rate: 1.0000e-05
# Epoch 252/300
# 704/704 - 44s - 62ms/step - accuracy: 0.9338 - loss: 0.3086 - val_accuracy: 0.9090 - val_loss: 0.4171 - learning_rate: 1.0000e-05
# Epoch 253/300
# 704/704 - 44s - 62ms/step - accuracy: 0.9318 - loss: 0.3097 - val_accuracy: 0.9090 - val_loss: 0.4132 - learning_rate: 1.0000e-05
# Epoch 254/300
# 704/704 - 44s - 63ms/step - accuracy: 0.9336 - loss: 0.3074 - val_accuracy: 0.9090 - val_loss: 0.4191 - learning_rate: 1.0000e-05
# Epoch 255/300
# 704/704 - 45s - 64ms/step - accuracy: 0.9338 - loss: 0.3088 - val_accuracy: 0.9088 - val_loss: 0.4194 - learning_rate: 1.0000e-05
# Epoch 255: early stopping
# Restoring model weights from the end of the best epoch: 215.

# %%
# Save the trained model
model.save('face_recognition_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from tensorflow.keras.models import load_model

# Load the saved model
model = load_model('face_recognition_model.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
plt.figure(figsize=(15,6))

# Plotting the training and validation loss
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss', color='#8502d1')
plt.plot(history.history['val_loss'], label='Validation Loss', color='darkorange')
plt.legend()
plt.title('Loss Evolution')

# Plotting the training and validation accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy', color='#8502d1')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', color='darkorange')
plt.legend()
plt.title('Accuracy Evolution')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-d4895bfa3789> in <cell line: 0>()
#       3 # Plotting the training and validation loss
#       4 plt.subplot(1, 2, 1)
# ----> 5 plt.plot(history.history['loss'], label='Train Loss', color='#8502d1')
#       6 plt.plot(history.history['val_loss'], label='Validation Loss', color='darkorange')
#       7 plt.legend()
#
# NameError: name 'history' is not defined

# %%
# Use the model to make predictions, evaluate on test data
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=1)

print('\nTest Accuracy:', test_acc)
print('Test Loss:    ', test_loss)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 28s 87ms/step - accuracy: 0.9062 - loss: 0.4324
#
# Test Accuracy: 0.9053999781608582
# Test Loss:     0.43105682730674744

# %% [markdown]
# Testing

# %%
# Read image from local path
image = cv2.imread("/content/dog..jpeg", cv2.IMREAD_COLOR)

# Convert from BGR to RGB
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
# Display the image
plt.imshow(image)
plt.xticks([])
plt.yticks([])
plt.grid(False)
plt.show()

# %%
# Resize it to 32x32 pixels
image = cv2.resize(image, (32,32))

# Normalize the image
image = (image-mean)/(std+1e-7)

# Add an extra dimension because the model expects a batch of images
image = image.reshape((1, 32, 32, 3))

# %%
prediction = model.predict(image)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step

# %%
predicted_class = prediction.argmax()

print('Predicted class: ', class_names[predicted_class])
# Out:
# Predicted class:  dog
